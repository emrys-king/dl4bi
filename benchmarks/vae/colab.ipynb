# %%
# !git clone https://github.com/emrys-king/dl4bi.git
# !pip install -q "jax[cuda12]" numpyro
# Out:
# fatal: destination path 'dl4bi' already exists and is not an empty directory.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 116.2 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 MB 17.7 MB/s eta 0:00:0000:0100:01

# %%
# !pip install dl4bi_sps
# !pip install dl4bi

# %%
# %cd /content/dl4bi
# !echo "3" | python benchmarks/vae/benchmark_matern_3_2.py
# Out:
# /content/dl4bi
# sample: 100% 14000/14000 [03:27<00:00, 67.53it/s, 31 steps of size 1.33e-01. acc. prob=0.90]
#
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#       beta      0.43      0.24      0.43      0.03      0.83   6452.83      1.00
#         ls      9.66      1.73      9.48      6.88     12.29   3490.10      1.00
#     z[0,0]      0.19      0.84      0.20     -1.22      1.56  12591.51      1.00
#     z[0,1]     -0.19      0.75     -0.19     -1.46      1.01  10856.13      1.00
#     z[0,2]     -0.47      0.77     -0.46     -1.75      0.76  15604.37      1.00
#     z[0,3]     -0.78      0.85     -0.77     -2.16      0.65  16088.06      1.00
#     z[0,4]     -0.01      0.99     -0.02     -1.66      1.56  15880.05      1.00
#     z[0,5]     -0.02      1.00     -0.03     -1.63      1.66  21393.03      1.00
#     z[0,6]      0.02      1.00      0.02     -1.66      1.63  18999.87      1.00
# ...

# %%
# !pip install gdown

# %%
# !mkdir -p benchmarks/vae/maps
# !gdown "https://drive.google.com/uc?id=12oPJGONKqSRLXH9h49LujIDQyFT18_tb" -O benchmarks/vae/maps/maps.zip
# !unzip benchmarks/vae/maps/maps.zip -d benchmarks/vae/maps/
# !rm benchmarks/vae/maps/maps.zip  # optional cleanup
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=12oPJGONKqSRLXH9h49LujIDQyFT18_tb
# From (redirected): https://drive.google.com/uc?id=12oPJGONKqSRLXH9h49LujIDQyFT18_tb&confirm=t&uuid=9e84d785-2a94-4925-89cf-80f3b37d0b73
# To: /content/dl4bi/benchmarks/vae/maps/maps.zip
# 100% 26.6M/26.6M [00:00<00:00, 29.1MB/s]
# Archive:  benchmarks/vae/maps/maps.zip
#    creating: benchmarks/vae/maps/maps/
#    creating: benchmarks/vae/maps/maps/London_MSOA_education_deprivation_parsed_thrs_0/
#   inflating: benchmarks/vae/maps/maps/London_MSOA_education_deprivation_parsed_thrs_0/education_deprivation_parsed_thrs_0.dbf
#   inflating: benchmarks/vae/maps/maps/London_MSOA_education_deprivation_parsed_thrs_0/education_deprivation_parsed_thrs_0.shx
#   inflating: benchmarks/vae/maps/maps/London_MSOA_education_deprivation_parsed_thrs_0/education_deprivation_parsed_thrs_0.shp
# ...

# %%
# !mv benchmarks/vae/maps/maps/* benchmarks/vae/maps/
# !rm -rf benchmarks/vae/maps/maps

# %% [markdown]
# !python benchmarks/vae/london_lsoa.py
